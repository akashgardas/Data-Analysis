# %% [markdown]
# <a href="https://colab.research.google.com/github/akashgardas/Machine-Learning/blob/day-10/day10/matplotlib/Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Matplotlib

# %%
# pip install matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
months = [
    'Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun',
    'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'
  ]
sales = [
    52341.67, 55189.24, 61783.10, 60456.98, 64221.45, 68910.88,
    70115.33, 67543.90, 72831.55, 78450.12, 95212.78, 115880.50,
  ]

# %% [markdown]
# ## Line Plot

# %%
plt.plot(months, sales, marker='o', linestyle='--')
plt.title('Monthly Sales Over an Year')
plt.xlabel('Month')
plt.ylabel('Sales(₹)')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Bar Plot

# %%
data = {
  'product': ['Quantum Widget', 'Hyper-Sprocket', 'Nano-Gear', 'Omega-Drive'],
  'revenue': [150000, 225500, 98000, 310200]
}

# %%
plt.bar(data['product'], data['revenue'], color='y')
plt.title('Revenue by Product Category')
plt.xlabel('Product')
plt.ylabel('Revenue(₹)')
plt.show()

# %% [markdown]
# ## Scatter Plot
# - To analyze relationship between two variables

# %%
age = np.random.randint(25, 60, 5)
salary = np.random.randint(30000, 100000, 5)
salary
# Out:
# array([35068, 79028, 64043, 53213, 41503])

# %%
plt.scatter(age, salary, color='g')
plt.title('Age vs Salary')
plt.xlabel('Age')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# ## Pie Chart

# %%
brands = ['Apple', 'Samgsung', 'OnePlus', 'Others']
market_share = [40, 30, 20, 10]
colors = ['gold', 'lightblue', 'lightgreen', 'pink']

# %%
plt.pie(market_share, labels=brands, colors=colors, autopct='%1.1f%%', startangle=90)
plt.title('Mobile Market Share')
plt.show()

# %%
browser_market_share = {
  'labels': ['Chrome', 'Safari', 'Edge', 'Firefox', 'Samsung Internet', 'Other'],
  'sizes': [65.3, 18.6, 5.5, 3.2, 3.1, 4.3]
}

# %%
plt.pie(
    browser_market_share['sizes'],
    labels=browser_market_share['labels'],
    counterclock=False,
    startangle=90,
    autopct='%1.1f%%'
)
plt.title('Browser Market Share')
plt.show()

# %% [markdown]
# ## Histogram
# - To show frequency distribution

# %%
ages = np.random.randint(18, 60, 100)

# %%
plt.hist(ages, bins=10, edgecolor='k')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %%
# exam scores
exam_scores = np.random.normal(loc=75, scale=10, size=1000)

# %%
plt.hist(exam_scores, bins=20, edgecolor='black', histtype='step')
plt.title('Exam Score Distribution')
plt.xlabel('Score')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ## Subplots

# %%
nums = np.arange(1, 6)
squares = np.power(nums, 2)
cubes = np.power(nums, 3)

# %%
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1) # row 1, cols 2, 1st plot
plt.plot(nums, squares, 'ro--') #
plt.title('Squares')
plt.xlabel('Number')
plt.ylabel('Square')

plt.subplot(1, 2, 2) # row 1, cols 2, 2nd plot
plt.plot(nums, cubes, 'g^')
plt.title('Cubes')
plt.xlabel('Number')
plt.ylabel('Cube')

plt.show()

# %%
x = np.linspace(0, 2 * np.pi, 400)
y1 = np.sin(x**2)
y2 = np.cos(x**2)

# %%
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(x, y1, 'b')
plt.title('Sine Wave')

plt.subplot(1, 2, 2)
plt.plot(x, y2, 'r')
plt.title('Cosine Wave')

plt.tight_layout()
plt.show()

# %%
sales = [ 52341.67, 55189.24, 61783.10, 60456.98, 64221.45, 68910.88 ]
profit = [ 10468.33, 11590.74, 13602.28, 12695.97, 12844.29, 14471.28,]
month = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun']

# %%
plt.plot(month, sales, label='Sales', marker='^', linestyle='-.')
plt.plot(month, profit, label='Profit', marker='s', linestyle='--')
plt.xlabel('Month')
plt.ylabel('Amount(₹)')
plt.title('Sales vs Profit')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# # Task
# -  Inspect the dataset and list the number of rows, columns, data types, and any missing values.
# -  Remove duplicate rows (if any) and re-check the dataset — how many rows were removed?
# -  Parse the Date column to datetime, sort the data by date, and report how many rows (if any) have invalid/missing dates.
# -  Handle missing values in numeric columns (explain and apply a method you choose), then state which method you used and why.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.listdir('drive/MyDrive/Tekworks')
# Out:
# ['Pulse_Calories.csv', 'Online_Retail.csv', 'Cleaned_Online_Retial_Data.csv']

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### Loading Dataset

# %%
df = pd.read_csv('drive/MyDrive/Tekworks/Pulse_Calories.csv')
df.head()
# Out:
#    Duration        Date  Pulse  Maxpulse  Calories
# 0        60  2020/12/01    110       130     409.1
# 1        60  2020/12/02    117       145     479.0
# 2        60  2020/12/03    103       135     340.0
# 3        45  2020/12/04    109       175     282.4
# 4        45  2020/12/05    117       148     406.0

# %% [markdown]
# ### Handling Missing values

# %%
df.describe()
# Out:
#          Duration       Pulse    Maxpulse    Calories
# count   32.000000   32.000000   32.000000   30.000000
# mean    68.437500  103.500000  128.500000  304.680000
# std     70.039591    7.832933   12.998759   66.003779
# min     30.000000   90.000000  101.000000  195.100000
# 25%     60.000000  100.000000  120.000000  250.700000
# 50%     60.000000  102.500000  127.500000  291.200000
# 75%     60.000000  106.500000  132.250000  343.975000
# max    450.000000  130.000000  175.000000  479.000000

# %%
df.isna().sum()
# Out:
# Duration    0
# Date        1
# Pulse       0
# Maxpulse    0
# Calories    2
# dtype: int64

# %%
df['Calories'] = df['Calories'].fillna(value=df['Calories'].mean())
df.describe()
# Out:
#          Duration       Pulse    Maxpulse    Calories
# count   32.000000   32.000000   32.000000   32.000000
# mean    68.437500  103.500000  128.500000  304.680000
# std     70.039591    7.832933   12.998759   63.839129
# min     30.000000   90.000000  101.000000  195.100000
# 25%     60.000000  100.000000  120.000000  250.700000
# 50%     60.000000  102.500000  127.500000  300.000000
# 75%     60.000000  106.500000  132.250000  341.325000
# max    450.000000  130.000000  175.000000  479.000000

# %%
df['Date'] = df['Date'].fillna(method='ffill')
df.isna().sum()
# Out:
# /tmp/ipython-input-3242631665.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Date'] = df['Date'].fillna(method='ffill')
# Duration    0
# Date        0
# Pulse       0
# Maxpulse    0
# Calories    0
# dtype: int64

# %% [markdown]
# ### Datatype conversion

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  32 non-null     int64
#  1   Date      32 non-null     object
#  2   Pulse     32 non-null     int64
#  3   Maxpulse  32 non-null     int64
#  4   Calories  32 non-null     float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 1.4+ KB

# %%
# datatype conversion
df['Date'] = pd.to_datetime(df['Date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  32 non-null     int64
#  1   Date      32 non-null     datetime64[ns]
#  2   Pulse     32 non-null     int64
#  3   Maxpulse  32 non-null     int64
#  4   Calories  32 non-null     float64
# dtypes: datetime64[ns](1), float64(1), int64(3)
# memory usage: 1.4 KB

# %% [markdown]
# ### Handling Duplicates

# %%
# removing duplicates
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df.drop_duplicates(inplace=True)
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Removing Outliers

# %%
# removing outliers - Duration
df['Duration'] = df['Duration'].clip(lower=df['Duration'].quantile(0.05), upper=df['Duration'].quantile(0.95))
df.describe()
# Out:
#         Duration                           Date       Pulse    Maxpulse  \
# count  31.000000                             31   31.000000   31.000000
# mean   56.612903  2020-12-15 23:13:32.903225856  103.612903  128.774194
# min    45.000000            2020-12-01 00:00:00   90.000000  101.000000
# 25%    60.000000            2020-12-08 12:00:00  100.000000  120.000000
# 50%    60.000000            2020-12-16 00:00:00  103.000000  128.000000
# 75%    60.000000            2020-12-23 12:00:00  107.000000  132.500000
# max    60.000000            2020-12-31 00:00:00  130.000000  175.000000
# std     6.375356                            NaN    7.935899   13.119222
#
#          Calories
# count   31.000000
# mean   306.421290
# min    195.100000
# 25%    252.000000
# 50%    300.000000
# 75%    342.650000
# max    479.000000
# std     64.117245

# %% [markdown]
# ### Sorting

# %%
# sorting by date
df.sort_values(by='Date', inplace=True)
df.head()
# Out:
#    Duration       Date  Pulse  Maxpulse  Calories
# 0        60 2020-12-01    110       130     409.1
# 1        60 2020-12-02    117       145     479.0
# 2        60 2020-12-03    103       135     340.0
# 3        45 2020-12-04    109       175     282.4
# 4        45 2020-12-05    117       148     406.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 31 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  31 non-null     int64
#  1   Date      31 non-null     datetime64[ns]
#  2   Pulse     31 non-null     int64
#  3   Maxpulse  31 non-null     int64
#  4   Calories  31 non-null     float64
# dtypes: datetime64[ns](1), float64(1), int64(3)
# memory usage: 1.5 KB

# %%
df.describe()
# Out:
#         Duration                           Date       Pulse    Maxpulse  \
# count  31.000000                             31   31.000000   31.000000
# mean   56.612903  2020-12-15 23:13:32.903225856  103.612903  128.774194
# min    45.000000            2020-12-01 00:00:00   90.000000  101.000000
# 25%    60.000000            2020-12-08 12:00:00  100.000000  120.000000
# 50%    60.000000            2020-12-16 00:00:00  103.000000  128.000000
# 75%    60.000000            2020-12-23 12:00:00  107.000000  132.500000
# max    60.000000            2020-12-31 00:00:00  130.000000  175.000000
# std     6.375356                            NaN    7.935899   13.119222
#
#          Calories
# count   31.000000
# mean   306.421290
# min    195.100000
# 25%    252.000000
# 50%    300.000000
# 75%    342.650000
# max    479.000000
# std     64.117245

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# ### Line Plot
#
# Create a line plot of Calories over Date (with markers, dashed line, grid, rotated x-ticks) and save the image as line_calories_over_time.png

# %%
plt.plot(df['Date'], df['Calories'], 'rx--')
plt.grid(True)
plt.xticks(rotation=45)
plt.title('Calories Over Time')
plt.xlabel('Date')
plt.ylabel('Calories')
# plt.savefig('line_calories_over_time.png')
plt.show()

# %%
plt.hist(df['Date'], edgecolor='k')
plt.xticks(rotation=45)
plt.xlabel('Date')
plt.ylabel('Frequency')
plt.title('Date Distribution')
plt.show()

# %% [markdown]
# ### Bar Chart
# Group data by Duration (or sensible duration bins), compute the average Pulse per group, and draw a bar chart comparing average pulse across duration groups; save as bar_avg_pulse_by_duration.png.

# %%
df.groupby('Duration')['Pulse'].mean()
# Out:
# Duration
# 45    103.857143
# 60    103.541667
# Name: Pulse, dtype: float64

# %%
plt.bar(df['Duration'], df['Pulse'])
plt.title('Average Pulse by Duration')
plt.xlabel('Duration')
plt.ylabel('Average Pulse')
plt.xticks(ticks=[45, 60])
# plt.savefig('bar_avg_pulse_by_duration.png')
plt.show()

# %% [markdown]
# ### Scatter Plot
# - Plot a scatter plot of Duration vs Calories, compute the Pearson correlation coefficient, and add a linear trend line to the scatter; save as scatter_duration_vs_calories.png.

# %%
plt.scatter(df['Duration'], df['Calories'])
plt.title('Duration vs Calories')
plt.xlabel('Duration')
plt.ylabel('Calories')
# plt.savefig('scatter_duration_vs_calories.png')
plt.show()

# %%
correlation = df['Duration'].corr(df['Calories'], method='pearson')
print(f"Pearson correlation coefficient between Duration and Calories: {correlation}")
# Out:
# Pearson correlation coefficient between Duration and Calories: 0.2272291505328814

# %%
plt.scatter(df['Duration'], df['Calories'])
plt.plot(df['Duration'], np.poly1d(np.polyfit(df['Duration'], df['Calories'], 1))(df['Duration']), color='r')
plt.title('Duration vs Calories')
plt.xlabel('Duration')
plt.ylabel('Calories')
# plt.savefig('scatter_duration_vs_calories_correlation.png')
plt.show()

# %% [markdown]
# ### Pie chart
# - Create a pie chart showing the percentage breakdown of Maxpulse into ranges (e.g., <=120, 121–140, 141–160, >160) and save as pie_maxpulse_ranges.png.

# %%
df['Maxpulse'].describe()
# Out:
# count     31.000000
# mean     128.774194
# std       13.119222
# min      101.000000
# 25%      120.000000
# 50%      128.000000
# 75%      132.500000
# max      175.000000
# Name: Maxpulse, dtype: float64

# %%
# defining ranges
bins=[0, 120, 140, 160, df['Maxpulse'].max()]
labels = ['<=120', '121-140', '141-160', '>160']

# categorizing data into ranges
df['Maxpulse_Range'] = pd.cut(df['Maxpulse'], bins=bins, labels=labels, right=True)
df.head()
# Out:
#    Duration       Date  Pulse  Maxpulse  Calories Maxpulse_Range
# 0        60 2020-12-01    110       130     409.1        121-140
# 1        60 2020-12-02    117       145     479.0        141-160
# 2        60 2020-12-03    103       135     340.0        121-140
# 3        45 2020-12-04    109       175     282.4           >160
# 4        45 2020-12-05    117       148     406.0        141-160

# %%
# value counts
maxpulse_counts = df['Maxpulse_Range'].value_counts()
maxpulse_counts
# Out:
# Maxpulse_Range
# 121-140    18
# <=120       9
# 141-160     3
# >160        1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8, 8))
plt.pie(maxpulse_counts, labels=maxpulse_counts.index, autopct='%1.1f%%', startangle=90, counterclock=False)
plt.title('Maxpulse Breakdown by Range')
# plt.savefig('pie_maxpulse_ranges.png')
plt.show()

# %% [markdown]
# ### Histogram
# - Plot a histogram of Calories with an appropriate number of bins, comment on shape/skewness, and save as hist_calories.png.

# %%
plt.hist(df['Calories'], bins=10, edgecolor='k')
plt.title('Histogram of Calories')
plt.xlabel('Calories')
plt.ylabel('Frequency')
# plt.savefig('hist_calories.png')
plt.show()

# %% [markdown]
# ### Multi Panel Subplot
#  - Build a multi-panel subplot figure (1 row × 2 columns): left = line plot of Pulse over Date, right = scatter of Duration vs Maxpulse; save as subplots_pulse_duration_maxpulse.png.

# %%
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(df['Date'], df['Pulse'])
plt.title('Pulse Over Time')
plt.xlabel('Date')
plt.xticks(rotation=45)
plt.ylabel('Pulse')
plt.grid(True)

plt.subplot(1, 2, 2)
plt.scatter(df['Duration'], df['Maxpulse'])
plt.title('Duration vs Maxpulse')
plt.xticks(ticks=[45, 60])
plt.xlabel('Duration')
plt.ylabel('Maxpulse')
plt.grid(True)

plt.tight_layout()
plt.show()
