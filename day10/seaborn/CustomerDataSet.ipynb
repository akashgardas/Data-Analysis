# %% [markdown]
# <a href="https://colab.research.google.com/github/akashgardas/Machine-Learning/blob/day-10/day10/seaborn/CustomerDataSet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Customer Dataset Visualization using Seaborn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Loading Dataset

# %%
df = pd.read_csv('drive/MyDrive/Tekworks/Customer_support_data.csv')
df.head()
# Out:
# /usr/local/lib/python3.12/dist-packages/google/colab/_dataframe_summarizer.py:88: UserWarning: Parsing dates in %d/%m/%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   cast_date_col = pd.to_datetime(column, errors="coerce")
#                               Unique id channel_name         category  \
# 0  7e9ae164-6a8b-4521-a2d4-58f7c9fff13f      Outcall  Product Queries
# 1  b07ec1b0-f376-43b6-86df-ec03da3b2e16      Outcall  Product Queries
# 2  200814dd-27c7-4149-ba2b-bd3af3092880      Inbound    Order Related
# 3  eb0d3e53-c1ca-42d3-8486-e42c8d622135      Inbound          Returns
# 4  ba903143-1e54-406c-b969-46c52f92e5df      Inbound     Cancellation
#
#                    Sub-category Customer Remarks  \
# 0                Life Insurance              NaN
# 1  Product Specific Information              NaN
# 2             Installation/demo              NaN
# ...

# %% [markdown]
# # Data Description

# %%
df.describe()
# Out:
#           Item_price  connected_handling_time    CSAT Score
# count   17206.000000               242.000000  85907.000000
# mean     5660.774846               462.400826      4.242157
# std     12825.728411               246.295037      1.378903
# min         0.000000                 0.000000      1.000000
# 25%       392.000000               293.000000      4.000000
# 50%       979.000000               427.000000      5.000000
# 75%      2699.750000               592.250000      5.000000
# max    164999.000000              1986.000000      5.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85907 entries, 0 to 85906
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unique id                85907 non-null  object
#  1   channel_name             85907 non-null  object
#  2   category                 85907 non-null  object
#  3   Sub-category             85907 non-null  object
#  4   Customer Remarks         28742 non-null  object
#  5   Order_id                 67675 non-null  object
#  6   order_date_time          17214 non-null  object
#  7   Issue_reported at        85907 non-null  object
#  8   issue_responded          85907 non-null  object
#  9   Survey_response_Date     85907 non-null  object
#  10  Customer_City            17079 non-null  object
#  11  Product_category         17196 non-null  object
#  12  Item_price               17206 non-null  float64
#  13  connected_handling_time  242 non-null    float64
# ...

# %% [markdown]
# ---
# # Data Cleaning

# %%
# skip - taken care for individual data required.

# %% [markdown]
# # Visualization
# (Task)

# %% [markdown]
# 3. “What is the spread of connected_handling_time values?” → Histogram +
# boxplot
# 4. “Can I see a pie chart of CSAT scores by their value?” → Pie chart
# 5. “What are the most common price ranges for items?” → Binned bar chart

# %% [markdown]
# ## 1A. Numerical Columns
# (Item_price, connected_handling_time, CSAT Score)

# %%
num_df = df[['Item_price', 'connected_handling_time', 'CSAT Score']]
num_df.describe()
# Out:
#           Item_price  connected_handling_time    CSAT Score
# count   17206.000000               242.000000  85907.000000
# mean     5660.774846               462.400826      4.242157
# std     12825.728411               246.295037      1.378903
# min         0.000000                 0.000000      1.000000
# 25%       392.000000               293.000000      4.000000
# 50%       979.000000               427.000000      5.000000
# 75%      2699.750000               592.250000      5.000000
# max    164999.000000              1986.000000      5.000000

# %%
num_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85907 entries, 0 to 85906
# Data columns (total 3 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Item_price               17206 non-null  float64
#  1   connected_handling_time  242 non-null    float64
#  2   CSAT Score               85907 non-null  int64
# dtypes: float64(2), int64(1)
# memory usage: 2.0 MB

# %% [markdown]
# ### 1. Show me the distribution of Item_price.
# → Histogram

# %%
# distribution of item_price
sns.histplot(num_df['Item_price'], kde=False)
plt.title('Distribution of Item Price')
plt.show()

# %% [markdown]
# ### 2. How does CSAT Score vary overall?
# → Boxplot

# %%
sns.boxplot(y=num_df['CSAT Score'])
plt.title('CSAT Score Distribution')
plt.show()

# %% [markdown]
# ### 3. What is the spread of connected_handling_time values?
# → Histogram + boxplot

# %%
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
sns.histplot(num_df['connected_handling_time'])
plt.title('Distribution of connected_handling_time')

plt.subplot(1, 2, 2)
sns.boxplot(y=num_df['connected_handling_time'])
plt.title('connected_handling_time Distribution')
plt.show()

# %% [markdown]
# ### 4. Can I see a pie chart of CSAT scores by their value?
#  → Pie chart

# %%
value_counts = num_df['CSAT Score'].value_counts()
value_counts
# Out:
# CSAT Score
# 5    59617
# 1    11230
# 4    11219
# 3     2558
# 2     1283
# Name: count, dtype: int64

# %%
plt.pie(x=value_counts, labels=value_counts.index, autopct='%1.1f%%')
plt.title('CSAT Score Distribution')
plt.show()

# %% [markdown]
# ### 5. What are the most common price ranges for items?
# → Binned bar chart

# %%
bins = [num_df['Item_price'].min(), 5000, 20000, num_df['Item_price'].max()]
labels = ['Low', 'Med', 'High']

num_df['Price_Range'] = pd.cut(df['Item_price'], bins=bins, labels=labels)
num_df.groupby('Price_Range')['Price_Range'].count()
# Out:
# /tmp/ipython-input-1497672445.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   num_df['Price_Range'] = pd.cut(df['Item_price'], bins=bins, labels=labels)
# /tmp/ipython-input-1497672445.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   num_df.groupby('Price_Range')['Price_Range'].count()
# Price_Range
# Low     13636
# Med      2082
# High     1487
# Name: Price_Range, dtype: int64

# %%
sns.barplot(data=num_df, x='Price_Range', y='Item_price')
plt.title('Price Range Distribution')
plt.show()

# %% [markdown]
# ## 1B. Categorical Columns
# (channel_name, category, Sub-category, Agent Shift,
# Tenure Bucket)

# %%
cat_df = df[['channel_name', 'category', 'Sub-category', 'Agent Shift', 'Tenure Bucket']]
cat_df.head()
# Out:
#   channel_name         category                  Sub-category Agent Shift  \
# 0      Outcall  Product Queries                Life Insurance     Morning
# 1      Outcall  Product Queries  Product Specific Information     Morning
# 2      Inbound    Order Related             Installation/demo     Evening
# 3      Inbound          Returns        Reverse Pickup Enquiry     Evening
# 4      Inbound     Cancellation                    Not Needed     Morning
#
#      Tenure Bucket
# 0  On Job Training
# 1              >90
# 2  On Job Training
# 3              >90
# 4             0-30

# %%
cat_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85907 entries, 0 to 85906
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   channel_name   85907 non-null  object
#  1   category       85907 non-null  object
#  2   Sub-category   85907 non-null  object
#  3   Agent Shift    85907 non-null  object
#  4   Tenure Bucket  85907 non-null  object
# dtypes: object(5)
# memory usage: 3.3+ MB

# %%
cat_df.describe()
# Out:
#        channel_name category            Sub-category Agent Shift Tenure Bucket
# count         85907    85907                   85907       85907         85907
# unique            3       12                      57           5             5
# top         Inbound  Returns  Reverse Pickup Enquiry     Morning           >90
# freq          68142    44097                   22389       41426         30660

# %% [markdown]
# ### 6. How many tickets come from each channel_name?
#  → Bar chart

# %%
cat_df.groupby('channel_name')['channel_name'].count()
# Out:
# channel_name
# Email       3023
# Inbound    68142
# Outcall    14742
# Name: channel_name, dtype: int64

# %%
channel_ticket_counts = cat_df['channel_name'].value_counts()

# %%
sns.barplot(x=channel_ticket_counts.index, y=channel_ticket_counts)
plt.title('Channel Name Distribution')
plt.show()

# %% [markdown]
# ### 7. Which category has the highest number of tickets?
#  → Bar chart (sorted)

# %%
category_tickets_count = df['category'].value_counts()
category_tickets_count.sort_values(ascending=False)
# Out:
# category
# Returns               44097
# Order Related         23215
# Refund Related         4550
# Product Queries        3692
# Shopzilla Related      2792
# Payments related       2327
# Feedback               2294
# Cancellation           2212
# Offers & Cashback       480
# Others                   99
# App/website              84
# Onboarding related       65
# Name: count, dtype: int64

# %%
sns.barplot(x=category_tickets_count.index, y=category_tickets_count)
plt.xticks(rotation=90)
plt.title('Category Distribution')
plt.show()

# %% [markdown]
# ### 8. Show me the distribution of tickets by Agent Shift.
#  → Pie chart

# %%
cat_df.groupby('Agent Shift')['Agent Shift'].count()
# Out:
# Agent Shift
# Afternoon     5840
# Evening      33677
# Morning      41426
# Night         1316
# Split         3648
# Name: Agent Shift, dtype: int64

# %%
agent_shift_ticket_count = cat_df['Agent Shift'].value_counts()
agent_shift_ticket_count
# Out:
# Agent Shift
# Morning      41426
# Evening      33677
# Afternoon     5840
# Split         3648
# Night         1316
# Name: count, dtype: int64

# %%
plt.pie(x=agent_shift_ticket_count, labels=agent_shift_ticket_count.index, autopct='%1.1f%%')
plt.title('Agent Shift Distribution')
plt.show()

# %% [markdown]
# ### 9. What are the top 10 Sub-category values?
#  → Horizontal bar chart

# %%
sub_category_ticket_count = cat_df['Sub-category'].value_counts()
sub_category_ticket_count.head(10)
# Out:
# Sub-category
# Reverse Pickup Enquiry          22389
# Return request                   8523
# Delayed                          7388
# Order status enquiry             6922
# Installation/demo                4116
# Fraudulent User                  4108
# Product Specific Information     3589
# Refund Enquiry                   2665
# Wrong                            2597
# Missing                          2556
# Name: count, dtype: int64

# %%
sns.barplot(x=sub_category_ticket_count.head(10), y=sub_category_ticket_count.head(10).index, orient='h')
plt.title('Top 10 Sub-category')
plt.show()

# %% [markdown]
# ### 10. How many tickets belong to each Tenure Bucket?
#  → Bar chart

# %%
tenure_bucket_ticket_count = cat_df['Tenure Bucket'].value_counts().sort_index()
tenure_bucket_ticket_count
# Out:
# Tenure Bucket
# 0-30               11318
# 31-60              11665
# 61-90               6741
# >90                30660
# On Job Training    25523
# Name: count, dtype: int64

# %%
sns.barplot(x=tenure_bucket_ticket_count.index, y=tenure_bucket_ticket_count)
plt.title('Tenure Bucket Distribution')
plt.show()

# %% [markdown]
# ---
# ## 2A. Numerical vs Numerical

# %% [markdown]
# ### 11. Is there a relationship between Item_price and CSAT Score?
#  → Scatter plot
#
#  Ans: No

# %%
sns.scatterplot(data=num_df, x='Item_price', y='CSAT Score')
plt.title('Item Price vs CSAT Score')
plt.show()

# %% [markdown]
# ### 12. How does connected_handling_time affect CSAT Score?
#  → Scatter plot + trend
# line

# %%
sns.scatterplot(data=num_df, x='connected_handling_time', y='CSAT Score')
sns.regplot(data=num_df, x='connected_handling_time', y='CSAT Score')
plt.title('connected_handling_time vs CSAT Score')
plt.show()

# %% [markdown]
# ### 13. Show me density or clusters of Item_price vs connected_handling_time.
#  → Hexbin plot

# %%
sns.jointplot(data=num_df, x='Item_price', y='connected_handling_time', kind='hex')
plt.title('Item Price vs connected_handling_time')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 2B. Numerical vs Categorical

# %%
# numerical + categorical columns
nc_df = df[['Item_price', 'connected_handling_time', 'CSAT Score', 'channel_name', 'category', 'Sub-category', 'Agent Shift', 'Tenure Bucket']]
nc_df.head()
# Out:
#    Item_price  connected_handling_time  CSAT Score channel_name  \
# 0         NaN                      NaN           5      Outcall
# 1         NaN                      NaN           5      Outcall
# 2         NaN                      NaN           5      Inbound
# 3         NaN                      NaN           5      Inbound
# 4         NaN                      NaN           5      Inbound
#
#           category                  Sub-category Agent Shift    Tenure Bucket
# 0  Product Queries                Life Insurance     Morning  On Job Training
# 1  Product Queries  Product Specific Information     Morning              >90
# 2    Order Related             Installation/demo     Evening  On Job Training
# 3          Returns        Reverse Pickup Enquiry     Evening              >90
# 4     Cancellation                    Not Needed     Morning             0-30

# %%
nc_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85907 entries, 0 to 85906
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Item_price               17206 non-null  float64
#  1   connected_handling_time  242 non-null    float64
#  2   CSAT Score               85907 non-null  int64
#  3   channel_name             85907 non-null  object
#  4   category                 85907 non-null  object
#  5   Sub-category             85907 non-null  object
#  6   Agent Shift              85907 non-null  object
#  7   Tenure Bucket            85907 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 5.2+ MB

# %% [markdown]
# ### 14. What is the CSAT Score per channel_name?
#  → Grouped bar chart

# %%
nc_df.groupby(['CSAT Score', 'channel_name'])['channel_name'].count()
# Out:
# CSAT Score  channel_name
# 1           Email             636
#             Inbound          8745
#             Outcall          1849
# 2           Email              64
#             Inbound          1011
#             Outcall           208
# 3           Email             102
#             Inbound          2033
#             Outcall           423
# 4           Email             388
#             Inbound          8934
#             Outcall          1897
# 5           Email            1833
#             Inbound         47419
#             Outcall         10365
# Name: channel_name, dtype: int64

# %%
sns.barplot(data=nc_df, x='channel_name', y='CSAT Score', hue='CSAT Score')
plt.title('CSAT Score per channel_name')
plt.grid(True)
plt.show()

# %% [markdown]
# ### 15. Show distribution of Item_price per category.
#  → Multiple boxplots

# %%
sns.boxplot(data=nc_df, x='category', y='Item_price')
plt.title('Item Price Distribution per Category')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### 16. How does connected_handling_time vary by Agent Shift?
#  → Boxplot

# %%
sns.boxplot(data=nc_df, x='Agent Shift', y='connected_handling_time')
plt.title('connected_handling_time by Agent Shift')
plt.show()

# %% [markdown]
# ### 17. Show mean and variability of Item_price across top 5 Product_category.
#  → Error bar plot

# %%
nc_df.groupby('category')['Item_price'].agg(['mean', 'std']).sort_values(by='mean', ascending=False).head(5)
# Out:
#                            mean           std
# category
# Offers & Cashback  15289.237288  20172.990502
# Shopzilla Related  13655.750000  16908.007436
# Payments related   10459.938776  13820.978423
# Product Queries     9187.764706  16246.599035
# Cancellation        8195.593516  15251.404147

# %%
# filtering top 5 categories
top_categories = nc_df.groupby('category')['Item_price'].mean().sort_values(ascending=False).head(5).index
top_categories_df = nc_df[df['category'].isin(top_categories)]
top_categories_df.groupby('category')['category'].count()
# Out:
# category
# Cancellation         2212
# Offers & Cashback     480
# Payments related     2327
# Product Queries      3692
# Shopzilla Related    2792
# Name: category, dtype: int64

# %%
sns.barplot(data=top_categories_df, x='category', y='Item_price', errorbar='sd')
plt.title('Mean and Variability of Item_price across top 5 Product_category')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### 18. How do CSAT scores differ across Tenure Bucket?
#  → Bar chart

# %%
nc_df.columns
# Out:
# Index(['Item_price', 'connected_handling_time', 'CSAT Score', 'channel_name',
#        'category', 'Sub-category', 'Agent Shift', 'Tenure Bucket'],
#       dtype='object')

# %%
nc_df.groupby('Tenure Bucket')['CSAT Score'].count()
# Out:
# Tenure Bucket
# 0-30               11318
# 31-60              11665
# 61-90               6741
# >90                30660
# On Job Training    25523
# Name: CSAT Score, dtype: int64

# %%
sns.barplot(data=nc_df.sort_values(by='Tenure Bucket'), x='Tenure Bucket', y='CSAT Score', hue='CSAT Score')
plt.title('CSAT Scores by Tenure Bucket')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 2C. Categorical vs Categorical

# %% [markdown]
# ### 19. Show the number of tickets by channel_name and category together.
#  → Stacked bar chart

# %%
nc_df.groupby(['channel_name', 'category'])['channel_name'].count()
# Out:
# channel_name  category
# Email         App/website               3
#               Cancellation             64
#               Feedback                122
#               Offers & Cashback        16
#               Order Related          1048
#               Others                    5
#               Payments related         54
#               Product Queries          10
#               Refund Related          436
#               Returns                1213
#               Shopzilla Related        52
# Inbound       App/website              62
#               Cancellation           1647
#               Feedback               1829
#               Offers & Cashback       404
#               Onboarding related       54
#               Order Related         18535
#               Others                   63
#               Payments related       1714
#               Product Queries        2847
#               Refund Related         3414
#               Returns               35419
# ...

# %%
sns.histplot(data=nc_df, x='category', hue='channel_name', multiple='stack')
plt.title('Tickets by channel_name and category')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 20. How does Agent Shift distribution differ across category?
#  → Stacked bar or
# grouped bar chart

# %%
sns.histplot(data=nc_df, x='category', hue='Agent Shift', multiple='stack')
plt.title('Agent Shift Distribution by Category')
plt.xticks(rotation=90)
plt.show()

# %%
sns.barplot(data=nc_df, x='category', y='Agent Shift', hue='Agent Shift')
plt.title('Agent Shift Distribution by Category')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ---
# ## 3. Temporal Columns

# %%
temporal_df = df[['order_date_time', 'Issue_reported at', 'Survey_response_Date']]
temporal_df.describe()
# Out:
#          order_date_time Issue_reported at Survey_response_Date
# count              17214             85907                85907
# unique             13766             30923                   31
# top     09/08/2023 11:55  13/08/2023 10:40            28-Aug-23
# freq                   7                13                 3452

# %%
temporal_df.head()
# Out:
# /usr/local/lib/python3.12/dist-packages/google/colab/_dataframe_summarizer.py:88: UserWarning: Parsing dates in %d/%m/%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   cast_date_col = pd.to_datetime(column, errors="coerce")
#   order_date_time Issue_reported at Survey_response_Date
# 0             NaN  01/08/2023 11:13            01-Aug-23
# 1             NaN  01/08/2023 12:52            01-Aug-23
# 2             NaN  01/08/2023 20:16            01-Aug-23
# 3             NaN  01/08/2023 20:56            01-Aug-23
# 4             NaN  01/08/2023 10:30            01-Aug-23

# %% [markdown]
# ### 21. How many tickets were created per day?
# → Line plot

# %%
tickets_per_day = temporal_df.groupby('Survey_response_Date')['Survey_response_Date'].count()
tickets_per_day.head()
# Out:
# Survey_response_Date
# 01-Aug-23    2231
# 02-Aug-23    2330
# 03-Aug-23    2467
# 04-Aug-23    2523
# 05-Aug-23    2283
# Name: Survey_response_Date, dtype: int64

# %%
plt.figure(figsize=(12, 4))
sns.lineplot(x=tickets_per_day.index, y=tickets_per_day)
plt.title('Tickets Created per Day')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### 22. Show daily trend of average CSAT Score.
# → Line plot (rolling average optional)

# %%
daily_csat_avg = df.groupby('Survey_response_Date')['CSAT Score'].mean()
daily_csat_avg.head()
# Out:
# Survey_response_Date
# 01-Aug-23    4.188256
# 02-Aug-23    4.186695
# 03-Aug-23    4.197811
# 04-Aug-23    4.216409
# 05-Aug-23    4.233027
# Name: CSAT Score, dtype: float64

# %%
daily_csat_avg.rolling(window=7).mean()
# Out:
# Survey_response_Date
# 01-Aug-23         NaN
# 02-Aug-23         NaN
# 03-Aug-23         NaN
# 04-Aug-23         NaN
# 05-Aug-23         NaN
# 06-Aug-23         NaN
# 07-Aug-23    4.209130
# 08-Aug-23    4.206855
# 09-Aug-23    4.204829
# 10-Aug-23    4.208688
# 11-Aug-23    4.210204
# 12-Aug-23    4.209951
# 13-Aug-23    4.209738
# 14-Aug-23    4.204286
# 15-Aug-23    4.211948
# 16-Aug-23    4.210626
# 17-Aug-23    4.205174
# 18-Aug-23    4.202410
# 19-Aug-23    4.199364
# 20-Aug-23    4.199403
# 21-Aug-23    4.211467
# 22-Aug-23    4.214413
# 23-Aug-23    4.232046
# 24-Aug-23    4.251536
# 25-Aug-23    4.259459
# 26-Aug-23    4.273042
# 27-Aug-23    4.285011
# 28-Aug-23    4.298635
# 29-Aug-23    4.314985
# 30-Aug-23    4.319628
# 31-Aug-23    4.315450
# Name: CSAT Score, dtype: float64

# %%
daily_csat_avg_rolling = daily_csat_avg.rolling(window=7).mean()

# %%
# Line plot with rolling average of 7 days
plt.figure(figsize=(12, 6))
sns.lineplot(x=daily_csat_avg.index, y=daily_csat_avg, label='Daily Average CSAT Score')
sns.lineplot(x=daily_csat_avg_rolling.index, y=daily_csat_avg_rolling, label='7-Day Rolling Average CSAT Score')

plt.title('Daily Trend of Average CSAT Score (with Rolling Average)')
plt.xlabel('Date')
plt.ylabel('Average CSAT Score')
plt.xticks(rotation=90)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Normal line plot
plt.figure(figsize=(12, 6))
sns.lineplot(data=df, x='Survey_response_Date', y='CSAT Score')
plt.title('Daily Trend of Average CSAT Score')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 23. Plot number of issues reported weekly.
# → Bar chart (aggregated)

# %%
temporal_df.columns
# Out:
# Index(['order_date_time', 'Issue_reported at', 'Survey_response_Date'], dtype='object')

# %%
# Dividing into bins
bins = [
    temporal_df['Issue_reported at'].min(),
    '07/08/2023 00:00',
    '14/08/2023 00:00',
    '21/08/2023 00:00',
    '28/08/2023 00:00',
    temporal_df['Issue_reported at'].max()
    ]

labels = ['Week 1', 'Week 2', 'Week 3', 'Week 4', 'Week 5']

temporal_df['Week'] = pd.cut(temporal_df['Issue_reported at'], bins=bins, labels=labels)
temporal_df.head()
# Out:
# /tmp/ipython-input-2396316863.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temporal_df['Week'] = pd.cut(temporal_df['Issue_reported at'], bins=bins, labels=labels)
# /usr/local/lib/python3.12/dist-packages/google/colab/_dataframe_summarizer.py:88: UserWarning: Parsing dates in %d/%m/%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   cast_date_col = pd.to_datetime(column, errors="coerce")
#   order_date_time Issue_reported at Survey_response_Date    Week
# 0             NaN  01/08/2023 11:13            01-Aug-23  Week 1
# 1             NaN  01/08/2023 12:52            01-Aug-23  Week 1
# ...

# %%
issues_weekly = temporal_df.groupby('Week')['Week'].count()
issues_weekly
# Out:
# /tmp/ipython-input-969187396.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   issues_weekly = temporal_df.groupby('Week')['Week'].count()
# Week
# Week 1    14414
# Week 2    20339
# Week 3    19089
# Week 4    20419
# Week 5    11645
# Name: Week, dtype: int64

# %%
# bar chart
sns.barplot(x=issues_weekly.index, y=issues_weekly)
plt.title('Number of Issues Reported Weekly')
plt.show()

# %% [markdown]
# - Alternative - Histplot

# %%
# Hist plot
sns.histplot(data=temporal_df, x='Week')
plt.title('Number of Issues Reported Weekly')
plt.show()

# %% [markdown]
# ### 24. What is the monthly pattern of ticket volume?
# → Line plot with month aggregation

# %%
# Convert 'Issue_reported at' to datetime objects
df['Issue_reported at'] = pd.to_datetime(df['Issue_reported at'], format='%d/%m/%Y %H:%M')

# Extract month from 'Issue_reported at'
df['Month'] = df['Issue_reported at'].dt.to_period('M')

# Group by month and count tickets
monthly_ticket_volume = df.groupby('Month').size()

# Plotting the line plot
plt.figure(figsize=(12, 6))
sns.lineplot(x=monthly_ticket_volume.index.astype(str), y=monthly_ticket_volume.values)
plt.title('Monthly Ticket Volume')
plt.xlabel('Month')
plt.ylabel('Number of Tickets')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 25. How does ticket volume differ by channel_name over time?
#  → Multi-line plot

# %%
# Group by date and channel_name and count tickets
ticket_volume_over_time = df.groupby([df['Issue_reported at'].dt.date, 'channel_name']).size().unstack(fill_value=0)

# Plotting the multi-line plot
plt.figure(figsize=(12, 6))
sns.lineplot(data=ticket_volume_over_time)
plt.title('Ticket Volume Over Time by Channel Name')
plt.xlabel('Date')
plt.ylabel('Number of Tickets')
plt.xticks(rotation=90)
plt.legend(title='Channel Name')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 26. Show the time lag between Issue_reported at and issue_responded.
#  → Line
# or scatter plot (response time trend)

# %%
# date format
df['issue_responded'] = pd.to_datetime(df['issue_responded'], format='%d/%m/%Y %H:%M')

# %%
issues_reported = df.groupby(df['Issue_reported at'].dt.date)['Issue_reported at'].count()
issues_reported_df = issues_reported.reset_index(name='count')
# issues_reported_df.columns = ['Date', 'Count']
issues_reported_df.head()
# Out:
#   Issue_reported at  count
# 0        2023-07-28      2
# 1        2023-07-29     20
# 2        2023-07-30     39
# 3        2023-07-31    191
# 4        2023-08-01   2238

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=issues_reported_df, x='Issue_reported at', y='count')
plt.title('Number of Issues Reported Over Time')
plt.xticks(rotation=90, ticks=issues_reported_df['Issue_reported at'])
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
lag_df = pd.DataFrame()
lag_df['Date'] = df['Issue_reported at'].dt.date
lag_df['Time_Lag'] = (df['issue_responded'] - df['Issue_reported at']).dt.total_seconds() / 60
lag_df.head()
# Out:
#          Date  Time_Lag
# 0  2023-08-01      34.0
# 1  2023-08-01       2.0
# 2  2023-08-01      22.0
# 3  2023-08-01      20.0
# 4  2023-08-01       2.0

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=lag_df, x='Date', y='Time_Lag')
plt.title('Time Lag between Issue_reported at and issue_responded')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 27. Show the volume of resolved issues over time.
#  → Line plot

# %%
resolved_issues_over_time = df.groupby(df['issue_responded'].dt.date)['issue_responded'].count()
resolved_issues_over_time_df = resolved_issues_over_time.reset_index(name='count')
resolved_issues_over_time_df.head()
# Out:
#   issue_responded  count
# 0      2023-08-01   2231
# 1      2023-08-02   2330
# 2      2023-08-03   2467
# 3      2023-08-04   2523
# 4      2023-08-05   2283

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=resolved_issues_over_time_df, x='issue_responded', y='count')
plt.title('Resolved Issues Over Time')
plt.xticks(ticks=resolved_issues_over_time_df['issue_responded'], rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 28. What is the peak hour or day for incoming tickets?
#  → Bar chart (hourly/daily
# distribution)

# %%
df.columns
# Out:
# Index(['Unique id', 'channel_name', 'category', 'Sub-category',
#        'Customer Remarks', 'Order_id', 'order_date_time', 'Issue_reported at',
#        'issue_responded', 'Survey_response_Date', 'Customer_City',
#        'Product_category', 'Item_price', 'connected_handling_time',
#        'Agent_name', 'Supervisor', 'Manager', 'Tenure Bucket', 'Agent Shift',
#        'CSAT Score', 'Month', 'response_time', 'response_time_hours'],
#       dtype='object')

# %%
# Extract hour and day of the week from 'Issue_reported at'
df['Issue_reported_hour'] = df['Issue_reported at'].dt.hour
df['Issue_reported_day'] = df['Issue_reported at'].dt.day_name()

# Count tickets per hour
hourly_ticket_volume = df['Issue_reported_hour'].value_counts().sort_index()

# Count tickets per day of the week
daily_ticket_volume = df['Issue_reported_day'].value_counts().reindex([
    'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'
])

# Plot hourly ticket volume
plt.figure(figsize=(12, 6))
sns.barplot(x=hourly_ticket_volume.index, y=hourly_ticket_volume.values)
plt.title('Hourly Ticket Volume')
plt.xlabel('Hour of Day')
plt.ylabel('Number of Tickets')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# Plot daily ticket volume
plt.figure(figsize=(12, 6))
sns.barplot(x=daily_ticket_volume.index, y=daily_ticket_volume.values)
plt.title('Daily Ticket Volume')
plt.xlabel('Day of Week')
plt.ylabel('Number of Tickets')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
